# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Simon Dagbanja**n\
# Data Scientist

# %% [markdown]
# *I'm intrested in data schience because i want to solve business problems*

# %% [markdown]
# ### My Salary for the week

# %%
hourly_rate = 50.00
hours_worked = 40

salary = hourly_rate + hours_worked
print(f"My Salary for this week is ${salary}")
# Out:
# My Salary for this week is $90.0

# %% [markdown]
# #### My favorite fruits bulleted list
# * Pineaple
# * Apple
# * Orange
#
# ***
#
# #### My favorite colors ordered list
# 1. Red
# 2. Cyan
# 3. Red
#
# ***
# #### My table
# | age | heigh |
# | --- | ---- |
# | 23 | 1.6 |
# | 20 | 1.4 |
#
# <a href="https://cloud.ibm.com/" target="_blank">Visit IBM Cloud Service</a>
